# %%
from data_generator import write_to_csv
write_to_csv('data_generation.csv', 10000)

# %%
import pandas as pd
data=pd.read_csv("data_generation.csv")
data.head()
# Out:
#                                Order_Id                           Customer_Id  \
# 0  fbca73c2-20dd-4fa3-8f58-896fa095b98b  2c8c616d-a738-44d3-a2f1-e853b63dcb00
# 1  d4876263-fda6-4238-81ae-9c90ee15bc88  30c90575-c9df-42dd-a120-0cb0b34085e6
# 2  86a41b72-a925-4c67-8307-ebcfe6ad58ac  30da8fa4-acf9-43f9-a3f0-c70902ad2ffb
# 3  0c93d203-f380-42b8-99d4-1b75396dbb5f  e97cb864-ba29-4da0-8163-d3b46b93b102
# 4  494f4c64-0f22-49be-9ad6-b9f6ef127f17  79ba68b5-f38f-4ce0-8401-0a10a5e27082
#
#     Customer_Name                            Product_Id Product_Category  \
# 0   Anthony Singh  108b3f71-5c83-4573-931c-5dad36155b6b           Sports
# 1   Erik Phillips  530548bf-076d-456e-89e4-28749b8a6dd5           Sports
# 2   Carrie Wilson  422eb5af-b232-427d-82ba-ba763d9d12c3      Electronics
# 3    Larry French  c4438da1-aa10-496c-a5a1-b174f4cf34b8            Books
# 4  Rebecca Wright  15c8b31b-4a40-4222-a03a-96c2201a9307      Electronics
#
#     Product_Name      Payment_Type  Quantity_ordered   Price  \
# 0  Tennis Racket               UPI                 5  438.28
# 1     Gym Gloves              Card                 4  259.57
# 2    Smartphones               UPI                 1  599.26
# 3      Magazines               UPI                 4  547.56
# 4    Smartphones  Internet Banking                 3   82.41
#
#   Date_and_Time_When_Order_Was_Placed Customer_Country Customer_City  \
# 0                 2020-12-31 04:42:58               UK    Manchester
# 1                 2023-08-22 07:36:21           Canada        Ottawa
# 2                 2022-06-06 10:35:39              USA      New York
# 3                 2021-12-23 07:17:00          Germany       Hamburg
# 4                 2021-08-12 21:52:15           Canada        Ottawa
#
#   Site_From_Where_Order_Was_Placed   Payment_Transaction_Confirmation_Id  \
# 0                             eBay  bc022562-1134-4730-bf04-93087207b99f
# 1                          Walmart  d2e2a42e-d200-4e39-afcd-c95ddca9687b
# 2                          Walmart  4014dacc-ec36-437a-9580-1305f27221bc
# 3                           Amazon  ec024601-7ccb-46cf-a518-d04389153b24
# 4                          Shopify  0966d75b-977c-4ebb-85af-17dcb02b6794
#
#   Payment_Success_or_Failure Payment_Failure_Reason
# 0                          Y     Payment Successful
# 1                          N           Card expired
# 2                          Y     Payment Successful
# 3                          N  Payment gateway error
# 4                          N     Insufficient funds

# %%
data.count()
# Out:
# Order_Id                               10000
# Customer_Id                            10000
# Customer_Name                          10000
# Product_Id                             10000
# Product_Category                       10000
# Product_Name                           10000
# Payment_Type                           10000
# Quantity_ordered                       10000
# Price                                  10000
# Date_and_Time_When_Order_Was_Placed    10000
# Customer_Country                       10000
# Customer_City                          10000
# Site_From_Where_Order_Was_Placed       10000
# Payment_Transaction_Confirmation_Id    10000
# Payment_Success_or_Failure             10000
# Payment_Failure_Reason                 10000
# dtype: int64

# %%
import Rough_data_generation as rough


num_records = 100  # Adjust as needed
orders_df = rough.generate_records(num_records)
rough.save_to_csv(orders_df, 'rough_data.csv')
# Out:
# Data saved to rough_data.csv

# %%
rough_data=pd.read_csv("rough_data.csv")
rough_data.head()
# Out:
#                                Order_Id                           Customer_Id  \
# 0                           InvalidUUID  123e4567-e89b-12d3-a456-426614174000
# 1  123e4567-e89b-12d3-a456-426614174001                     InvalidCustomerId
# 2  123e4567-e89b-12d3-a456-426614174002  123e4567-e89b-12d3-a456-426614174002
# 3  123e4567-e89b-12d3-a456-426614174003  123e4567-e89b-12d3-a456-426614174003
# 4  123e4567-e89b-12d3-a456-426614174004  123e4567-e89b-12d3-a456-426614174004
#
#   Customer_Name                            Product_Id Product_Name  \
# 0    Customer_0  123e4567-e89b-12d3-a456-426614174000     Widget C
# 1    Customer_1  123e4567-e89b-12d3-a456-426614174001     Widget B
# 2    Customer_2                      InvalidProductId     Widget A
# 3    Customer_3  123e4567-e89b-12d3-a456-426614174003     Widget A
# 4    Customer_4  123e4567-e89b-12d3-a456-426614174004     Widget E
#
#   Product_Category   Payment_Type  Quantity_ordered   Price  \
# 0            Books    Credit Card                 4  676.85
# 1            Books  Bank Transfer                 5   242.6
# 2      Electronics  Bank Transfer                 5  666.94
# 3  InvalidCategory      Gift Card                 4  907.89
# 4      Electronics  Bank Transfer                -1  137.01
#
#   Date_and_Time_When_Order_Was_Placed Customer_Country Customer_City  \
# 0          2024-03-05 14:32:02.014241              USA        City_0
# 1          2023-12-18 14:32:02.014241              USA        City_1
# 2          2024-04-16 14:32:02.014241              USA        City_2
# 3          2023-11-26 14:32:02.014241              USA        City_3
# 4          2023-10-26 14:32:02.014241               UK        City_4
#
#   Site_From_Where_Order_Was_Placed   Payment_Transaction_Confirmation_Id  \
# 0                             eBay  123e4567-e89b-12d3-a456-426614174000
# 1                          Shopify  123e4567-e89b-12d3-a456-426614174001
# 2                         Flipkart  123e4567-e89b-12d3-a456-426614174002
# 3                         Flipkart  123e4567-e89b-12d3-a456-426614174003
# 4                          Walmart  123e4567-e89b-12d3-a456-426614174004
#
#   Payment_Success_or_Failure Payment_Failure_Reason
# 0                          Y                    NaN
# 1                          N                    NaN
# 2                          Y     Insufficient Funds
# 3                          N  Payment Gateway Error
# 4                          N                    NaN

# %%
rough_data.count()
# Out:
# Order_Id                               100
# Customer_Id                            100
# Customer_Name                          100
# Product_Id                             100
# Product_Name                           100
# Product_Category                       100
# Payment_Type                           100
# Quantity_ordered                       100
# Price                                  100
# Date_and_Time_When_Order_Was_Placed    100
# Customer_Country                       100
# Customer_City                          100
# Site_From_Where_Order_Was_Placed       100
# Payment_Transaction_Confirmation_Id    100
# Payment_Success_or_Failure             100
# Payment_Failure_Reason                  48
# dtype: int64

# %%
# main.py
from data_handling import load_data, save_data, generate_fake_data

def main(input_file, output_file):
    """Main function to process the CSV file."""
    df = load_data(input_file)
    df = generate_fake_data(df)
    save_data(df, output_file)
    print("Data processed and saved successfully!")

# Define your input and output CSV file paths
input_file = 'rough_data.csv'  # Replace with your input CSV file path
output_file = 'handling_rough_data.csv'  # Define your output CSV file path

# Call the main function with the defined paths
main(input_file, output_file)
# Out:
# Data processed and saved successfully!

# %%
data=pd.read_csv("handling_rough_data.csv")

# %%
data.columns
# Out:
# Index(['Order_Id', 'Customer_Id', 'Customer_Name', 'Product_Id',
#        'Product_Category', 'Product_Name', 'Quantity_ordered', 'Price',
#        'Date_and_Time_When_Order_Was_Placed', 'Customer_Country',
#        'Customer_City', 'Site_From_Where_Order_Was_Placed', 'Payment_Type',
#        'Payment_Transaction_Confirmation_Id', 'Payment_Success_or_Failure',
#        'Payment_Failure_Reason'],
#       dtype='object')

# %%
data.head()
# Out:
#                                Order_Id                           Customer_Id  \
# 0  1da64e40-8649-4568-9eee-2167ce50af2c  123e4567-e89b-12d3-a456-426614174000
# 1  123e4567-e89b-12d3-a456-426614174001  411ec6d7-824b-44dc-bb5e-7b2e865cff3a
# 2  123e4567-e89b-12d3-a456-426614174002  123e4567-e89b-12d3-a456-426614174002
# 3  123e4567-e89b-12d3-a456-426614174003  123e4567-e89b-12d3-a456-426614174003
# 4  123e4567-e89b-12d3-a456-426614174004  123e4567-e89b-12d3-a456-426614174004
#
#      Customer_Name                            Product_Id Product_Category  \
# 0   Elizabeth Pope  123e4567-e89b-12d3-a456-426614174000           Sports
# 1    Sharon Barton  123e4567-e89b-12d3-a456-426614174001         Clothing
# 2  Jennifer Franco  6a0d4d3f-ccbf-4a79-ba62-ed7382b20898            Books
# 3     Amber Newton  123e4567-e89b-12d3-a456-426614174003      Electronics
# 4     Daniel Smith  123e4567-e89b-12d3-a456-426614174004   Home & Kitchen
#
#   Product_Name  Quantity_ordered   Price Date_and_Time_When_Order_Was_Placed  \
# 0     Football                 4  676.85          2024-03-05 14:32:02.014241
# 1        Socks                 5  242.60          2023-12-18 14:32:02.014241
# 2  Non-Fiction                 5  666.94          2024-04-16 14:32:02.014241
# 3  Smartphones                 4  907.89          2023-11-26 14:32:02.014241
# 4   Toothpaste                 1  137.01          2023-10-26 14:32:02.014241
#
#   Customer_Country Customer_City Site_From_Where_Order_Was_Placed  \
# 0               UK    Birmingham                             eBay
# 1               UK       Glasgow                          Shopify
# 2           Canada        Ottawa                         Flipkart
# 3               UK    Manchester                         Flipkart
# 4          Germany        Munich                          Walmart
#
#   Payment_Type   Payment_Transaction_Confirmation_Id  \
# 0       Wallet  123e4567-e89b-12d3-a456-426614174000
# 1          UPI  123e4567-e89b-12d3-a456-426614174001
# 2       Wallet  123e4567-e89b-12d3-a456-426614174002
# 3       Wallet  123e4567-e89b-12d3-a456-426614174003
# 4         Card  123e4567-e89b-12d3-a456-426614174004
#
#   Payment_Success_or_Failure Payment_Failure_Reason
# 0                          Y     No Reason Provided
# 1                          N     No Reason Provided
# 2                          Y     Insufficient Funds
# 3                          N  Payment Gateway Error
# 4                          N     No Reason Provided
